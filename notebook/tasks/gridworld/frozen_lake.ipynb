# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../../')
import numpy as np
import numpy.random as npr
import time
from pyrl.tasks.gridworld.frozen_lake import FrozenLake
from IPython.display import HTML, clear_output, display
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
desc = np.asarray(
'''
SFFF
FHFH
FFFH
HFFG
'''.strip().split('\n'), dtype='c')

# %%
lake = FrozenLake(desc)

# %%
state = 0
for i in range(100):
    state = lake.step(state, npr.randint(0, 4))
    if lake.end_state(state): break
    clear_output(wait=True)
    display(HTML(lake.visualize(state)))
    time.sleep(0.1)
# Out:
#                             <center>
#                                 Frozen Lake (4 x 4)
#                                 <img style="width: 200px" src="...%...%2BvrtfnoCO3p6/DE9gR19uXO/l%...%2BHA7PYEdPT3%...%2Bv9xMT2BHz4fD9AR2taYHsKPX77%...%2BGaCMbcVF%2BUQAAAABJRU5ErkJggg%3D%3D"></img>
#                             </center>

# %%
state
# Out:
# 15

# %%
lake.state_to_pos(4)
# Out:
# (1, 0)

# %%
lake.pos_to_state((0,3))
# Out:
# 3

# %%
lake.step(4, 1)
# Out:
# 8

# %%
display(HTML(lake.visualize(4)))
# Out:
# (1, 0)
#                             <center>
#                                 Frozen Lake (4 x 4)
#                                 <img style="width: 200px" src="...%2BnaQAADO9JREFUeJzt2TFOFVAURVG/%...%2BkJbHQ7PQD4b2ut6QnAK%..."></img>
#                             </center>
